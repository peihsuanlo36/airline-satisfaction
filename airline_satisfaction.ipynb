# %%
# import package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px
import sklearn

# %%
# import data
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
test.info()


# clean useless columns
train = train.drop(["Unnamed: 0","id"], axis=1)
test = test.drop(["Unnamed: 0","id"], axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25976 entries, 0 to 25975
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         25976 non-null  int64
#  1   id                                 25976 non-null  int64
#  2   Gender                             25976 non-null  object
#  3   Customer Type                      25976 non-null  object
#  4   Age                                25976 non-null  int64
#  5   Type of Travel                     25976 non-null  object
#  6   Class                              25976 non-null  object
#  7   Flight Distance                    25976 non-null  int64
#  8   Inflight wifi service              25976 non-null  int64
#  9   Departure/Arrival time convenient  25976 non-null  int64
#  10  Ease of Online booking             25976 non-null  int64
# ...

# %%
# merge data
df = train.append(test)

# check na & clean missing values
df.isnull()
train = train.dropna(axis="rows")
test = test.dropna(axis="rows")
df = df.dropna(axis="rows")
##df.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %%
## Graph
import plotly.express as px
fig = px.sunburst(train, path=["satisfaction","Type of Travel" ], color_continuous_scale="RdBu")
fig.show()

# %%
## EDA
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns


# Pie chart for Gender
gender = df["Gender"].value_counts()
gender_count = gender.values.tolist() #provide numeral values
gender_type = gender.axes[0].tolist()
plt.figure(figsize=(12,8))
plt.pie(
    gender_count, 
    labels=gender_type, 
    autopct="%1.1f%%",
    textprops = {"fontsize" : 20},
    colors = ['#F38181','#EAFFD0'],
    explode=(0,0))
plt.axis("equal")
for text,autotext in zip(texts,autotexts):
    text.set_fontsize(14)
    autotext.set_fontsize(14)


# bar chart for satisfaction
# 分布圖 for departure & arrival delay + mean
# 分布圖 for distance + mean
# average for each and total (service)

# %%
# Pie chart for Class
Class = df["Class"].value_counts()
class_count = Class.values.tolist() #provide numeral values
class_type = Class.axes[0].tolist()
plt.figure(figsize=(12,8))
texts, autotexts=plt.pie(class_count, 
                         labels = class_type,
                         autopct="%1.1f%%",
                         textprops = {"fontsize" : 20},
                         colors = ['#95E1D3','#FCE38A','#BDE4F4'],
                         explode = (0,0,0)
                        )

plt.axis("equal")

# %%
# Pie chart for Customer type
CT = df["Customer Type"].value_counts()
CT_count = CT.values.tolist() #provide numeral values
CT_type = CT.axes[0].tolist()
plt.figure(figsize=(12,8))
plt.pie(
    CT_count, 
    labels = CT_type, 
    autopct="%1.1f%%",
    textprops = {"fontsize":20},
    colors = ['#95E1D3','#FCE38A','#BDE4F4'],
    explode=(0,0))
plt.axis("equal")
for text,autotext in zip(texts,autotexts):
    text.set_fontsize(14)
    autotext.set_fontsize(14)

# // 是忠誠客戶的滿意比例會較高?

# %%
# Pie chart for Type of travel
TT = df["Type of Travel"].value_counts()
TT_count = TT.values.tolist() #provide numeral values
TT_type = TT.axes[0].tolist()
plt.figure(figsize=(12,8))
plt.pie(
    TT_count, 
    labels = TT_type, 
    autopct="%1.1f%%",
    textprops = {"fontsize":20},
    colors = ['#95E1D3','#FCE38A','#BDE4F4'],
    explode=(0,0))
plt.axis("equal")
for text,autotext in zip(texts,autotexts):
    text.set_fontsize(14)
    autotext.set_fontsize(14)

# %%
# bar chart for Age
with sns.axes_style("white"):
    g = sns.catplot("Age",
                    data=df,
                    aspect=3.0,
                    kind="count",
                    order=range(5,80,5))
    g.set_ylabels("Amount")

# %%
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns


# satisfaction
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.countplot(data=df, x="satisfaction" , palette="Paired")
plt.title("Satisfaction")
plt.legend()


gender = df["satisfaction"].value_counts()
gender_count = gender.values.tolist() #provide numeral values
gender_type = gender.axes[0].tolist()
plt.figure(figsize=(12,8))
plt.pie(
    gender_count, 
    labels=gender_type, 
    autopct="%1.1f%%",
    textprops = {"fontsize" : 20},
    colors = ['#F38181','#EAFFD0'],
    explode=(0,0))
plt.axis("equal")
for text,autotext in zip(texts,autotexts):
    text.set_fontsize(14)
    autotext.set_fontsize(14)
# Out:
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7b4f20166506> in <module>
#      24     explode=(0,0))
#      25 plt.axis("equal")
# ---> 26 for text,autotext in zip(texts,autotexts):
#      27     text.set_fontsize(14)
#      28     autotext.set_fontsize(14)
#
# NameError: name 'texts' is not defined

# %%
# boxplot
import pandas as pd
import seaborn as sns

# %%
# Inflight wifi service
with sns.axes_style('white'):
    g = sns.catplot(y="Inflight wifi service", data=df, kind="box", height=4.5, aspect=.8)

# %%
# Departure/Arrival time convenient
with sns.axes_style('white'):
    g = sns.catplot(y="Departure/Arrival time convenient", data=df, kind="box", height=4.5, aspect=.8)

# %%
# Ease of Online booking
with sns.axes_style('white'):
    g = sns.catplot(y="Ease of Online booking", data=df, kind="box", height=7, aspect=.8)

# %%
# Departure/Arrival time convenient
with sns.axes_style('white'):
    g = sns.catplot(y="Departure/Arrival time convenient", data=df, kind="box", height=4.5, aspect=.8)

# %%
numerical_features = df.select_dtypes(exclude=['object']).copy()

numerical_features = df.select_columns(exclude = ['Age','Flight Distance','Departure Delay in Minutes','Arrival Delay in Minutes'])

# %%
numerical_features.drop(['Age','Flight Distance','Departure Delay in Minutes','Arrival Delay in Minutes'])

# %%
fig = plt.figure(figsize=(15,30))
for i in range(len(numerical_features.columns)):
    fig.add_subplot(9,4,i+1)
    sns.boxplot(y=numerical_features.iloc[:,i])

plt.tight_layout()
plt.show()

# %%
# correlation
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
corr = df.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))
f, ax = plt.subplots(figsize=(20, 20))
cmap = sns.diverging_palette(150, 1, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=None, center=0,square=True, annot=True, linewidths=.5, cbar_kws={"shrink": .9})

# %%
## dummy translate //by lebalencoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

train_ob = []
for col in train.columns:
    if train[col].dtype=="object":
        train_ob.append(col)
        
for v1 in train[train_ob]:
    train[v1]=le.fit_transform(train[v1])

test_ob= []    
for col in test.columns:
    if test[col].dtype=="object":
        test_ob.append(col)

for v2 in test[test_ob]:
    test[v2]=le.fit_transform(test[v2])   
    
df_ob= []    
for col in df.columns:
    if df[col].dtype=="object":
        df_ob.append(col)

for v3 in df[df_ob]:
    df[v3]=le.fit_transform(df[v3])   

# gender >>> Male:1 /Female:0
# customer type >>> Loyal Customer:0 / disloyal Customer: 1
# type of travel >>> Personal Travel:0 / Business travel:1
# class >>> Business:0 / Eco: 1 / Eco Plus: 2
# satisfaction >>> neutral or dissatisfied:0 / satisfied:1

df.isnull()
df.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       1              0   13               1      2              460
# 1       1              1   25               0      0              235
# 2       0              0   26               0      0             1142
# 3       0              0   25               0      0              562
# 4       1              0   61               0      0              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# ...

# %%
# logistic Regression
from sklearn.linear_model import LogisticRegression
X_train = train.drop("satisfaction", axis=1)
y_train = train["satisfaction"]
X_test = test.drop("satisfaction", axis=1)
y_test = test["satisfaction"]
print("X_train",len(X_train))
print("X_test",len(X_test))
print("y_train",len(y_train))
print("y_test",len(y_test))
print("test",len(test))
# Out:
# X_train 103594
# X_test 25893
# y_train 103594
# y_test 25893
# test 25893

# %%
logreg=LogisticRegression()
logreg.fit(X_train,y_train)
acc_log_train=round(logreg.score(X_train,y_train)*100,2)
acc_log_test=round(logreg.score(X_test,y_test)*100,2)
print("Training Accuracy: % {}".format(acc_log_train))
print("Test Accuracy: % {}".format(acc_log_test))
# Out:
# Training Accuracy: % 81.69
# Test Accuracy: % 81.73
# D:\ana\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
from sklearn.metrics import confusion_matrix
y_pred=logreg.predict(X_test)
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True,fmt="d") 
plt.show()

# %%
from sklearn.metrics import confusion_matrix
y_pred=logreg.predict(X_train)
cm=confusion_matrix(y_train,y_pred)
sns.heatmap(cm,annot=True,fmt="d") 
plt.show()

# %%
# factor analytics
# !pip install factor_analyzer
# Out:
# ...
#   Created wheel for factor-analyzer: filename=factor_analyzer-0.3.2-py3-none-any.whl size=40383 sha256=84ecd362c837307df4f45701808d42584cf60580f6053251e853b442c7b19499
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\8d\9e\4c\fd4cb92cecf157b13702cc0907e5c56ddc48e5388134dc9f1a
# Successfully built factor-analyzer
# ...

# %%
from factor_analyzer import FactorAnalyzer # Then, we import the installed package into our notebook.

# %%
# instantiate the Factor Analyzer
fa = FactorAnalyzer() 

# Fit the dataframe using Factor Analyzer
df1 = df.drop(["satisfaction","Gender","Flight Distance","Class","Type of Travel","Age","Customer Type"], axis=1)

fa.fit(df1)

# Identify the eigenvalues
ev, v = fa.get_eigenvalues() #eigenvalues

# display the eigenvalues
ev
# Out:
# array([3.80389837, 2.3721328 , 2.16956004, 1.96182794, 1.06300589,
#        0.94961228, 0.69607891, 0.53723377, 0.51374997, 0.46784182,
#        0.36634408, 0.32884042, 0.29332142, 0.25443665, 0.18743275,
#        0.03468288])

# %%
fa = FactorAnalyzer(4, rotation='varimax')
fa.fit(df1)
print(fa.loadings_)

lmatrix = pd.DataFrame(fa.loadings_, index = list(df1.columns), columns = ['Factor 1', 'Factor 2', 'Factor 3', 'Factor 4'])
lmatrix #loading matrix
# Out:
# [[ 0.16705917  0.12910325  0.75843442 -0.01006224]
#  [-0.03274439  0.05827162  0.5038348   0.00102873]
#  [ 0.03022112  0.02308306  0.93057187 -0.00325953]
#  [-0.03474282 -0.03296849  0.50705373  0.00639417]
#  [ 0.75313711  0.01216387  0.00424407 -0.01682119]
#  [ 0.39382113  0.11439334  0.36031702 -0.01278466]
#  [ 0.79113843  0.08154278  0.02620254 -0.01380499]
#  [ 0.74587902  0.46808683  0.01089797 -0.00661217]
#  [ 0.09076163  0.70189458  0.02757195 -0.01892449]
#  [ 0.0736754   0.48408253  0.08057279  0.02334515]
#  [ 0.02321895  0.76612457  0.02645767  0.00781858]
#  [ 0.14025455  0.28533738  0.02692701 -0.01346995]
#  [ 0.01775651  0.79969753  0.01666035 -0.0432629 ]
#  [ 0.85795299  0.09029215 -0.00334125  0.00154039]
#  [-0.0169373  -0.01502782 -0.00121591  0.96743387]
#  [-0.01895086 -0.0201893  -0.00282685  0.99711235]]
#                                    Factor 1  Factor 2  Factor 3  Factor 4
# ...

# %%
# standardization

from sklearn.preprocessing import StandardScaler

df_sub = df
sc = StandardScaler()
sc.fit(df_sub)
df_std = sc.transform(df_sub)

# %%
wcss= []
for k in range(1, 11):
    kmeans = KMeans(n_clusters = k, init = 'random')
    kmeans.fit(df_std)
    wcss.append(kmeans.inertia_)

# %%
# elbow plot
plt.figure(figsize = (10, 7))
plt.plot(range(1, 11), wcss, linewidth = 2, marker = '8')
plt.title('Elbow Plot\n', fontsize = 20)
plt.xlabel('K')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters = 3)
labels = kmeans.fit_predict(df_std)
print(labels)

# %%
plt.figure(figsize = (12, 8))

plt.scatter(df_std[:, 0], df_std[:, 1], c = kmeans.labels_, s = 105)
plt.title('Clusters of Customers\n', fontsize = 20)
plt.xlabel('Age')
plt.ylabel('Flight Distance')
plt.show()

# %%
# kmeans
from sklearn.cluster import KMeans
import numpy as np
km = KMeans()
X = np.random.rand(100, 2)
km.fit(X)
print(km.labels_)


from sklearn.cluster import KMeans
import numpy as np
kmeans = KMeans(init="random",n_clusters=3,random_state=0)
kmeans.fit(df_std)
labels = pd.Series(kmeans.lebals_, name="cluster_number")
print(lebals.value_counts(sort=False))
ax = lebals.values_counts(sort=False).plot(kind="bar")
ax.set_xlebal("cluster number")
ax.set_ylebal("count")

# %%
kmeans = KMeans(init="random",n_clusters=3,random_state=0)
kmeans.fit(df_std)
cluster_num = kmeans.predict(df_std)
df_std.info()


# merge data
k_df = df
m_df = pd.concat([pd.DataFrame(df_std[:,0]), pd.DataFrame(df_std[:,1]), pd.DataFrame(cluster_num)], axis=1)
m_df.columns = ["f1","f2","cluster"]

# %%
ax = None
for i, data in m_df.groupby("cluster"):
    ax =data.plot.scatter(x="f1",y="f2",label= f"cluster{i}", ax=ax)

# %%
# clean N/A
train = train.dropna(inplace=True)
test = test.dropna(inplace=True)
df = df.dropna(inplace=True)
